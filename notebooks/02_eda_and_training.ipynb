# %% [markdown]
# # 02 - EDA and Training
#
# Exploratory analysis and model training. See `train_model.py` for the full pipeline.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/career_dataset.csv")
df.head()

# %%
df["career"].value_counts().plot(kind="bar", figsize=(10, 4))
plt.title("Career Distribution")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# %run ../train_model.py
